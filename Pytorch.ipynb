# %% [markdown]
# <a href="https://colab.research.google.com/github/CYBERCONQUEROR/Pytorch/blob/main/Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x= torch.tensor(3.0, requires_grad=True)

# %%
y=x**2

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z=torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)
